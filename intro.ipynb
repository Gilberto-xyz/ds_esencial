# %% [markdown]
# # Python para ciencia de datos y big data escencial

# %%
import pandas as pd

# %%
dataframe = pd.read_csv('../dataset/base_datos_2008.csv')

# %%
dataframe
# Out:
#          Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0        2008      1           3          4   2003.0        1955   2211.0
# 1        2008      1           3          4    754.0         735   1002.0
# 2        2008      1           3          4    628.0         620    804.0
# 3        2008      1           3          4    926.0         930   1054.0
# 4        2008      1           3          4   1829.0        1755   1959.0
# ...       ...    ...         ...        ...      ...         ...      ...
# 7009723  2008     12          13          6   1002.0         959   1204.0
# 7009724  2008     12          13          6    834.0         835   1021.0
# 7009725  2008     12          13          6    655.0         700    856.0
# 7009726  2008     12          13          6   1251.0        1240   1446.0
# 7009727  2008     12          13          6   1110.0        1103   1413.0
#
#          CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# ...

# %%
# Exploar las filas que tenemos, de manera desordenada
# Esto va bien cuando deseamos trabar con datos aleatorios y no solo con los primeros 10 elementos de los datos
# mejorando la muestra para mejores resultados
dataframe.sample( frac = 1)
# Out:
#          Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 78655    2008      1          27          7   1155.0        1200   1508.0
# 975780   2008      2          27          3   1341.0        1340   1457.0
# 4991452  2008      9          26          5   1830.0        1840   2142.0
# 5235566  2008      9          17          3   1301.0        1310   1400.0
# 2001531  2008      4          16          3    735.0         745    854.0
# ...       ...    ...         ...        ...      ...         ...      ...
# 498851   2008      1          29          2    754.0         800    854.0
# 3628669  2008      7          10          4   1020.0        1020   1118.0
# 3651395  2008      7          17          4   1831.0        1815   1917.0
# 7005942  2008     12          10          3   1704.0        1655   1947.0
# 2102016  2008      4          27          7    916.0         920   1139.0
#
#          CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# ...

# %%
# Explorar las columnas que tenemos
dataframe.columns
# Out:
# Index(['Year', 'Month', 'DayofMonth', 'DayOfWeek', 'DepTime', 'CRSDepTime',
#        'ArrTime', 'CRSArrTime', 'UniqueCarrier', 'FlightNum', 'TailNum',
#        'ActualElapsedTime', 'CRSElapsedTime', 'AirTime', 'ArrDelay',
#        'DepDelay', 'Origin', 'Dest', 'Distance', 'TaxiIn', 'TaxiOut',
#        'Cancelled', 'CancellationCode', 'Diverted', 'CarrierDelay',
#        'WeatherDelay', 'NASDelay', 'SecurityDelay', 'LateAircraftDelay'],
#       dtype='object')

# %%
# Muestra los tipos de datos de cada columna del dataframe
dataframe.dtypes
# Out:
# Year                   int64
# Month                  int64
# DayofMonth             int64
# DayOfWeek              int64
# DepTime              float64
# CRSDepTime             int64
# ArrTime              float64
# CRSArrTime             int64
# UniqueCarrier         object
# FlightNum              int64
# TailNum               object
# ActualElapsedTime    float64
# CRSElapsedTime       float64
# AirTime              float64
# ArrDelay             float64
# DepDelay             float64
# Origin                object
# Dest                  object
# Distance               int64
# TaxiIn               float64
# TaxiOut              float64
# Cancelled              int64
# CancellationCode      object
# Diverted               int64
# CarrierDelay         float64
# WeatherDelay         float64
# NASDelay             float64
# SecurityDelay        float64
# LateAircraftDelay    float64
# dtype: object

# %%
# Mostrar los objetos que tenemos 
dataframe.values
# Out:
# array([[2008, 1, 3, ..., nan, nan, nan],
#        [2008, 1, 3, ..., nan, nan, nan],
#        [2008, 1, 3, ..., nan, nan, nan],
#        ...,
#        [2008, 12, 13, ..., nan, nan, nan],
#        [2008, 12, 13, ..., nan, nan, nan],
#        [2008, 12, 13, ..., nan, nan, nan]], dtype=object)

# %%
# Podemos guardar los datos de una consulta grande o pequeña para poder trabajar de manera independiente
# Esto requiere espacio de memoria pero es comodo para realizar pruebas 

df2 = dataframe.head(100)

# %%
df2
# Out:
#     Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0   2008      1           3          4   2003.0        1955   2211.0
# 1   2008      1           3          4    754.0         735   1002.0
# 2   2008      1           3          4    628.0         620    804.0
# 3   2008      1           3          4    926.0         930   1054.0
# 4   2008      1           3          4   1829.0        1755   1959.0
# ..   ...    ...         ...        ...      ...         ...      ...
# 95  2008      1           3          4   1506.0        1440   2030.0
# 96  2008      1           3          4   2039.0        1930    155.0
# 97  2008      1           3          4    924.0         920   1209.0
# 98  2008      1           3          4   1611.0        1535   1849.0
# 99  2008      1           3          4   1824.0        1715    117.0
#
#     CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# ...
