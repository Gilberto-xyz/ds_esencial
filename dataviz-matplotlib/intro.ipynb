# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

df = pd.read_csv('C:/Users/G/Documents/dataset/base_datos_2008.csv', nrows = 100000)

# %%
# Tabla resumen de los datos de vuelos cancelados
data = np.unique( df.Cancelled, return_counts = True)
data
# Out:
# (array([0, 1], dtype=int64), array([98858,  1142], dtype=int64))

# %%
# Grafico de pay
plt.pie(x = data[1],
        labels = data[0],
        # colors = ['Red', 'Gray'], 
        shadow = True,
        startangle = 90,
        radius = 2
        )

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
