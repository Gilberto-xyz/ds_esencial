# %% [markdown]
# # Filtrar datos en python

# %%
import pandas as pd

df = pd.read_csv('../dataset/base_datos_2008.csv')
df
# Out:
#          Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0        2008      1           3          4   2003.0        1955   2211.0
# 1        2008      1           3          4    754.0         735   1002.0
# 2        2008      1           3          4    628.0         620    804.0
# 3        2008      1           3          4    926.0         930   1054.0
# 4        2008      1           3          4   1829.0        1755   1959.0
# ...       ...    ...         ...        ...      ...         ...      ...
# 7009723  2008     12          13          6   1002.0         959   1204.0
# 7009724  2008     12          13          6    834.0         835   1021.0
# 7009725  2008     12          13          6    655.0         700    856.0
# 7009726  2008     12          13          6   1251.0        1240   1446.0
# 7009727  2008     12          13          6   1110.0        1103   1413.0
#
#          CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# ...

# %%
# Mostrar los primeros 20 elementos dentro de la columna ArrDelay
df['ArrDelay'].head(20)
# Out:
# 0    -14.0
# 1      2.0
# 2     14.0
# 3     -6.0
# 4     34.0
# 5     11.0
# 6     57.0
# 7    -18.0
# 8      2.0
# 9    -16.0
# 10     1.0
# 11    80.0
# 12     1.0
# 13    10.0
# 14    -4.0
# 15    11.0
# 16    15.0
# 17   -15.0
# 18    16.0
# 19    37.0
# Name: ArrDelay, dtype: float64

# %%
# Mostrar del registro 100 hasta el registro 200 
df[100 : 200]
# Out:
#      Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 100  2008      1           3          4    826.0         825    930.0
# 101  2008      1           3          4   2118.0        2015   2224.0
# 102  2008      1           3          4   1818.0        1740   1916.0
# 103  2008      1           3          4    650.0         650    748.0
# 104  2008      1           3          4   2146.0        2055   2250.0
# ..    ...    ...         ...        ...      ...         ...      ...
# 195  2008      1           3          4   1613.0        1610   1721.0
# 196  2008      1           3          4   2015.0        1945   2101.0
# 197  2008      1           3          4    655.0         655    742.0
# 198  2008      1           3          4   1438.0        1435   1533.0
# 199  2008      1           3          4   1102.0        1030   1152.0
#
#      CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# ...

# %%
# Filtro avanzado
# Llamamos al dataframe con el que estamos trabajando y entre corchetes los valores que deseamos obtener 
df[ df['ArrDelay'] > 60].head()
# Out:
#     Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 11  2008      1           3          4   1644.0        1510   1845.0
# 30  2008      1           3          4   2107.0        1945   2334.0
# 37  2008      1           3          4   1812.0        1650   1927.0
# 49  2008      1           3          4   2245.0        1730   2354.0
# 77  2008      1           3          4    958.0         900   1052.0
#
#     CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 11        1725            WN       1333  ...    6.0      8.0          0
# 30        2230            WN        362  ...    6.0      7.0          0
# 37        1815            WN        422  ...    6.0     11.0          0
# 49        1850            WN        186  ...    3.0      7.0          0
# 77         950            WN       1574  ...    4.0     14.0          0
#
#     CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# ...

# %%
# Mostrar todos los vuelos que no se retrasaron 60 minutos
df[ df['ArrDelay'] != 60].head()
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  2008      1           3          4   2003.0        1955   2211.0
# 1  2008      1           3          4    754.0         735   1002.0
# 2  2008      1           3          4    628.0         620    804.0
# 3  2008      1           3          4    926.0         930   1054.0
# 4  2008      1           3          4   1829.0        1755   1959.0
#
#    CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 0        2225            WN        335  ...    4.0      8.0          0
# 1        1000            WN       3231  ...    5.0     10.0          0
# 2         750            WN        448  ...    3.0     17.0          0
# 3        1100            WN       1746  ...    3.0      7.0          0
# 4        1925            WN       3920  ...    3.0     10.0          0
#
#    CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# ...

# %%
# Mostrar todos los vuelos que tardaron igual o menos de 60 minutos
df[ df['ArrDelay'] <= 60]
# Out:
#          Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0        2008      1           3          4   2003.0        1955   2211.0
# 1        2008      1           3          4    754.0         735   1002.0
# 2        2008      1           3          4    628.0         620    804.0
# 3        2008      1           3          4    926.0         930   1054.0
# 4        2008      1           3          4   1829.0        1755   1959.0
# ...       ...    ...         ...        ...      ...         ...      ...
# 7009723  2008     12          13          6   1002.0         959   1204.0
# 7009724  2008     12          13          6    834.0         835   1021.0
# 7009725  2008     12          13          6    655.0         700    856.0
# 7009726  2008     12          13          6   1251.0        1240   1446.0
# 7009727  2008     12          13          6   1110.0        1103   1413.0
#
#          CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# ...

# %%
# Aplica con texto tambien

df[ df['Origin'] == 'ATL'].head()
# Out:
#         Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 103149  2008      1          21          1   1207.0        1210   1346.0
# 103572  2008      1          12          6   1458.0        1500   1622.0
# 104019  2008      1          20          7   1403.0        1330   1625.0
# 104124  2008      1          26          6   1629.0        1630   1832.0
# 104485  2008      1           4          5   1336.0        1340   1501.0
#
#         CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 103149        1335            XE       2349  ...   11.0     13.0          0
# 103572        1620            XE       2145  ...    6.0     17.0          0
# 104019        1608            XE       1284  ...    6.0     32.0          0
# 104124        1902            XE       1241  ...    9.0     15.0          0
# 104485        1500            XE       2112  ...   12.0     12.0          0
#
# ...

# %%
# Mostrar todos los vuelos de origen Houston o Atlanta
df[ df['Origin'].isin(['HOU', 'ATL'])].head()
# Out:
#       Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 3269  2008      1           4          5   1910.0        1910   2025.0
# 3270  2008      1           4          5   1345.0        1345   1453.0
# 3271  2008      1           4          5    736.0         735    839.0
# 3272  2008      1           4          5   1603.0        1550   1647.0
# 3273  2008      1           4          5   2105.0        2105   2151.0
#
#       CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 3269        2025            WN        823  ...    6.0     11.0          0
# 3270        1500            WN        901  ...    3.0     14.0          0
# 3271         850            WN        957  ...    3.0      9.0          0
# 3272        1635            WN        231  ...    5.0     10.0          0
# 3273        2150            WN        570  ...    7.0     11.0          0
#
#       CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# ...

# %%
# Mostrar todos los registros que no tienen nada asignado en ArrDelay
# Dataset en el Dataframe
#   pandas is no asigned 
#            dataframe ArrDelay
df[ pd.isna( df['ArrDelay'])].head()
# Out:
#      Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 178  2008      1           3          4      NaN         700      NaN
# 373  2008      1           3          4      NaN        1100      NaN
# 399  2008      1           3          4      NaN         905      NaN
# 401  2008      1           3          4      NaN        1620      NaN
# 415  2008      1           3          4      NaN        1930      NaN
#
#      CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 178         830            WN        126  ...    NaN      NaN          1
# 373        1215            WN       1146  ...    NaN      NaN          1
# 399        1025            WN        469  ...    NaN      NaN          1
# 401        1740            WN        618  ...    NaN      NaN          1
# 415        2035            WN       2528  ...    NaN      NaN          1
#
#      CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# ...

# %%
# mostrar cuatos registros estan vacios
len( df[ pd.isna( df['ArrDelay'])])
# Out:
# 154699
